# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/Miscellaneous/blob/main/%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA%D0%B8_%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --force-reinstall 'sqlalchemy<2.0.0'
# Out:
# ...
#   Using cached SQLAlchemy-1.4.51-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# ...
#   Using cached greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.3
#     Uninstalling greenlet-3.0.3:
#       Successfully uninstalled greenlet-3.0.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.51
#     Uninstalling SQLAlchemy-1.4.51:
#       Successfully uninstalled SQLAlchemy-1.4.51
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.51 which is incompatible.
# ...

# %%
import pandas as pd

# %%
Tabl_City=pd.read_sql(""" Select * from City """, "postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db")

# %%
Tabl_City.head()
# Out:
#    id            name country_code       district  population
# 0   1           Kabul          AFG          Kabol     1780000
# 1   2        Qandahar          AFG       Qandahar      237500
# 2   3           Herat          AFG          Herat      186800
# 3   4  Mazar-e-Sharif          AFG          Balkh      127800
# 4   5       Amsterdam          NLD  Noord-Holland      731200

# %%
len(Tabl_City)
# Out:
# 4079

# %%
Tabl_City.describe()
# Out:
#                 id    population
# count  4079.000000  4.079000e+03
# mean   2040.000000  3.504682e+05
# std    1177.650203  7.237757e+05
# min       1.000000  4.200000e+01
# 25%    1020.500000  1.147890e+05
# 50%    2040.000000  1.670510e+05
# 75%    3059.500000  3.106385e+05
# max    4079.000000  1.050000e+07

# %%
Tabl_City.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4079 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4079 non-null   int64
#  1   name          4079 non-null   object
#  2   country_code  4079 non-null   object
#  3   district      4079 non-null   object
#  4   population    4079 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 159.5+ KB

# %%
Tabl_City.columns
# Out:
# Index(['id', 'name', 'country_code', 'district', 'population'], dtype='object')

# %% [markdown]
# ищем мои города через sql-запрос:

# %%
name=pd.read_sql(""" Select name from City """, "postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db")

# %%
name # ищем тут через фильтры, либо можно скопировать в гугл-таблицу
# Out:
#                 name
# 0              Kabul
# 1           Qandahar
# 2              Herat
# 3     Mazar-e-Sharif
# 4          Amsterdam
# ...              ...
# 4074      Khan Yunis
# 4075          Hebron
# 4076        Jabaliya
# 4077          Nablus
# 4078           Rafah
#
# [4079 rows x 1 columns]

# %% [markdown]
# Другой вариант, не через sql-запрос:

# %%
Tabl_City[['name', 'country_code']] # аналогично ищем тут через фильтры, либо можно скопировать в гугл-таблицу
# Out:
#                 name country_code
# 0              Kabul          AFG
# 1           Qandahar          AFG
# 2              Herat          AFG
# 3     Mazar-e-Sharif          AFG
# 4          Amsterdam          NLD
# ...              ...          ...
# 4074      Khan Yunis          PSE
# 4075          Hebron          PSE
# 4076        Jabaliya          PSE
# 4077          Nablus          PSE
# 4078           Rafah          PSE
#
# [4079 rows x 2 columns]

# %%
Vacations=pd.read_csv('Итоги.csv', ','); Vacations
# Out:
# <ipython-input-162-d13708e56d5f>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   Vacations=pd.read_csv('Итоги.csv', ','); Vacations
#        Отметка времени   Страна            Город Дата начала отпуска  \
# 0   1/31/2024 19:27:25   Турция          Станбул            5/1/2021
# 1   1/31/2024 19:28:40      ОАЭ            Дубай           8/16/2021
# 2   1/31/2024 19:30:17   Россия  Санкт-Петербург           11/1/2021
# 3   1/31/2024 19:37:13   Россия           Москва          12/25/2021
# 4   1/31/2024 19:39:31  Тайланд          Бангкок           2/12/2022
# 5   1/31/2024 19:40:28   Грузия           Батуми            5/1/2022
# 6   1/31/2024 19:41:37   Турция          Анталья           6/11/2022
# 7   1/31/2024 19:43:05   Россия        Геленджик           9/19/2022
# 8   1/31/2024 19:44:35      ОАЭ            Дубай           1/18/2023
# ...

# %% [markdown]
# При помощи SQL и Python получите датафрейм с названием города и его населением из таблицы city:

# %%
popl_name=pd.read_sql(""" Select name, population from City """, "postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"); popl_name
# Out:
#                 name  population
# 0              Kabul     1780000
# 1           Qandahar      237500
# 2              Herat      186800
# 3     Mazar-e-Sharif      127800
# 4          Amsterdam      731200
# ...              ...         ...
# 4074      Khan Yunis      123175
# 4075          Hebron      119401
# 4076        Jabaliya      113901
# 4077          Nablus      100231
# 4078           Rafah       92020
#
# [4079 rows x 2 columns]

# %% [markdown]
# При помощи Python соедините данные из выгруженного csv файла (пункт 8) и таблицы с населением города:

# %%
final_table=Vacations.merge(popl_name, left_on='Tabl_City', right_on='name', how='inner'); final_table
# Out:
#       Отметка времени   Страна            Город Дата начала отпуска  \
# 0  1/31/2024 19:27:25   Турция          Станбул            5/1/2021
# 1  1/31/2024 19:28:40      ОАЭ            Дубай           8/16/2021
# 2  1/31/2024 19:44:35      ОАЭ            Дубай           1/18/2023
# 3  1/31/2024 19:30:17   Россия  Санкт-Петербург           11/1/2021
# 4  1/31/2024 19:37:13   Россия           Москва          12/25/2021
# 5  1/31/2024 19:39:31  Тайланд          Бангкок           2/12/2022
# 6  1/31/2024 19:40:28   Грузия           Батуми            5/1/2022
# 7  1/31/2024 19:41:37   Турция          Анталья           6/11/2022
# 8  1/31/2024 19:45:37   Россия           Казань            5/6/2023
# 9  1/31/2024 19:47:33   Грузия          Тбилиси          12/23/2023
#
#   Дата окончания отпуска  Планируемый бюждет  Стоимость билетов  \
# 0              5/10/2021             50000.0            30000.0
# 1              8/31/2021             80000.0            25000.0
# ...

# %% [markdown]
# Сгруппируйте итоговый датафрейм по странам и рассчитайте среднюю численность населения в городах, в которых вы отдыхали:

# %%
final_table.groupby('Страна').mean()
# Out:
# <ipython-input-165-a5005f791d74>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_table.groupby('Страна').mean()
#          Планируемый бюждет  Стоимость билетов  Стоимость отеля  \
# Страна
# Грузия         70000.000000            17500.0          25000.0
# ОАЭ           100000.000000            25000.0          37500.0
# Россия         43333.333333            10000.0          19000.0
# Тайланд       100000.000000            20000.0          30000.0
# Турция         65000.000000            30000.0          25000.0
#
#          Траты на отдыхе  Общая оценка отпуска по шкале от 1 до 5  \
# Страна
# Грузия           25000.0                                 4.000000
# ОАЭ              42500.0                                 5.000000
# ...
