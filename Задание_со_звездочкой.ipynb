# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/Miscellaneous/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D1%81%D0%BE_%D0%B7%D0%B2%D0%B5%D0%B7%D0%B4%D0%BE%D1%87%D0%BA%D0%BE%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('Траты.csv',',')
# Out:
# <ipython-input-2-36d93a686b57>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df=pd.read_csv('Траты.csv',',')

# %%
df.head()
# Out:
#    январь  февраль  март  апрель
# 0    4600     6309  5690    4789
# 1    3400     4567  2398    2890
# 2    1267     3459  7812    7832
# 3    2304     1239  3451    9840
# 4    3427     3298  3480    1290

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   январь   8 non-null      int64
#  1   февраль  8 non-null      int64
#  2   март     8 non-null      int64
#  3   апрель   8 non-null      int64
# dtypes: int64(4)
# memory usage: 384.0 bytes

# %%
df.describe()
# Out:
#             январь      февраль         март       апрель
# count     8.000000     8.000000     8.000000     8.000000
# mean   2634.125000  3293.000000  3646.125000  4126.625000
# std    1592.439408  1720.218508  2376.576015  3312.271078
# min     345.000000  1209.000000   479.000000   240.000000
# 25%    1257.750000  2041.500000  2123.000000  1695.000000
# 50%    2852.000000  3378.500000  3465.500000  3596.000000
# 75%    3695.250000  4107.250000  4843.250000  5549.750000
# max    4600.000000  6309.000000  7812.000000  9840.000000

# %%
x=df[['январь','февраль','март']]
y=df[['апрель']]

# %%
x
# Out:
#    январь  февраль  март
# 0    4600     6309  5690
# 1    3400     4567  2398
# 2    1267     3459  7812
# 3    2304     1239  3451
# 4    3427     3298  3480
# 5    4500     2309  1298
# 6    1230     3954  4561
# 7     345     1209   479

# %%
y
# Out:
#    апрель
# 0    4789
# 1    2890
# 2    7832
# 3    9840
# 4    1290
# 5    4302
# 6    1830
# 7     240

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
X_train
# Out:
#    январь  февраль  март
# 3    2304     1239  3451
# 5    4500     2309  1298
# 0    4600     6309  5690
# 2    1267     3459  7812
# 4    3427     3298  3480
# 1    3400     4567  2398

# %%
X_test
# Out:
#    январь  февраль  март
# 6    1230     3954  4561
# 7     345     1209   479

# %%
y_train
# Out:
#    апрель
# 3    9840
# 5    4302
# 0    4789
# 2    7832
# 4    1290
# 1    2890

# %%
y_test
# Out:
#    апрель
# 6    1830
# 7     240

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[ 0.24603134, -1.32680408,  0.96732772]])

# %%
lr.predict(X_test)
# Out:
# array([[4619.79487608],
#        [4095.50259498]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 11323927.855254505

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 3703662.8093905062

# %%
data = [{
    "январь": 20123,
    "февраль": 12567,
    "март": 34567
}]

# %%
df_april = pd.DataFrame(data)
df_april.head()
# Out:
#    январь  февраль   март
# 0   20123    12567  34567

# %%
lr.predict(df_april)
# Out:
# array([[26865.93695165]])
