# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/Miscellaneous/blob/main/%D0%BC%D0%BE%D0%B9_%D0%BF%D0%B5%D1%80%D0%B2%D1%8B%D0%B9_%D0%BA%D0%BE%D0%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Ответы.csv', ',')
# Out:
# <ipython-input-29-4d00480ae359>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df=pd.read_csv('Ответы.csv', ',')

# %%
df.head()
# Out:
#       Отметка времени Месяц операции        Название операции    Сумма  \
# 0  1/27/2024 17:42:25         Январь  Продукты в супермаркете  12000.0
# 1  1/27/2024 17:43:48         Январь                   бензин   3500.0
# 2  1/27/2024 17:44:29         Январь       лекарства в аптеке   1500.0
# 3  1/27/2024 17:44:51         Январь               коммуналка   9000.0
# 4  1/27/2024 17:45:08        Февраль         оплата интернета   1000.0
#
#                         Категория Регулярная трата Месяц операции_1
# 0                             Еда           ИСТИНА        01 Январь
# 1                            Авто           ИСТИНА        01 Январь
# 2                        Здоровье             ЛОЖЬ        01 Январь
# 3            Коммунальные платежи           ИСТИНА        01 Январь
# 4  Интернет, телефон, телевидение           ИСТИНА       02 Февраль

# %%
len(df)
# Out:
# 37

# %%
df.describe()
# Out:
#                Сумма
# count      37.000000
# mean     7431.081081
# std     16802.535157
# min       200.000000
# 25%       800.000000
# 50%      2000.000000
# 75%      8000.000000
# max    100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Отметка времени    37 non-null     object
#  1   Месяц операции     37 non-null     object
#  2   Название операции  37 non-null     object
#  3   Сумма              37 non-null     float64
#  4   Категория          37 non-null     object
#  5   Регулярная трата   37 non-null     object
#  6   Месяц операции_1   37 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.1+ KB

# %%
df.columns
# Out:
# Index(['Отметка времени', 'Месяц операции', 'Название операции', 'Сумма',
#        'Категория', 'Регулярная трата', 'Месяц операции_1'],
#       dtype='object')

# %%
df.groupby('Категория').sum()
# Out:
# <ipython-input-38-163882b6e892>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Категория').sum()
#                                    Сумма
# Категория
# Авто                             10250.0
# Еда                              64000.0
# Здоровье                         11000.0
# Интернет, телефон, телевидение    3500.0
# Коммунальные платежи             42000.0
# Прочее                            8000.0
# Путешествия                     130000.0
# Транспорт                         6200.0
